# %%
import pandas as pd
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By # By es para buscar por tag, clase, id...



# %pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Configuro el controlador de Chrome
driver = webdriver.Chrome()

# Navegar a la página web
driver.get("https://transparencia.archimadrid.es/ingresos-y-gastos-2020/")

# %%
# Localizo el botón
boton = driver.find_element(By.TAG_NAME, "strong")

# Pulso el botón
boton.click()

# Cierro el navegador
#driver.quit()

boton.text
# Out:
# 'Descargar tabla'

# %%
df2020 = pd.read_excel('Estado de Ingresos y Gastos  Madrid  2020.xls') # Visualizo la tabla

df
# Out:
#     Unnamed: 0                        ARCHIDIÓCESIS DE MADRID   Unnamed: 2  \
# 0          NaN                    ESTADO DE INGRESOS Y GASTOS          NaN
# 2          NaN                                       INGRESOS          NaN
# 3          NaN                                            NaN          NaN
# 4          1.0                     APORTACIONES DE LOS FIELES          NaN
# 5          NaN                      1.1 Colectas parroquiales  10218112.20
# 6          NaN                              1.2 Suscripciones  15197539.00
# 7          NaN                       1.3 Donativos y limosnas   9700395.64
# 8          NaN  1.4 Colectas para instituciones de la Iglesia   2784078.16
# 9          NaN                       1.5 Cáritas Parroquiales   6998562.81
# 10         NaN                        1.6 Herencias y Legados   2377354.91
# 11         NaN                                            NaN          NaN
# ...

# %%
filas_a_eliminar = [1, 31, 32, 33, 34]            #elimino filas
df2020 = df2020.drop(filas_a_eliminar, axis=0)

# %%
df.tail()
# Out:
#     Unnamed: 0                     ARCHIDIÓCESIS DE MADRID  Unnamed: 2  \
# 26         NaN  5.1 Plusvalías enajenaciones de patrimonio    86994.28
# 27         NaN          5.2 Otros ingresos extraordinarios  4542077.98
# 28         NaN                                         NaN         NaN
# 29         NaN                                         NaN         NaN
# 30         NaN                              TOTAL INGRESOS         NaN
#
#       Unnamed: 3 Unnamed: 4  Unnamed: 5  \
# 26           NaN        NaN         NaN
# 27           NaN        NaN         NaN
# 28           NaN        NaN         NaN
# 29           NaN        NaN         NaN
# 30  1.060931e+08        NaN         NaN
#
#                             EJERCICIO DE 2020  Unnamed: 7    Unnamed: 8  \
# 26  6.3 Minusvalias enajenacion de patrimonio  2089314.51           NaN
# 27           6.4 Otros Gastos Extraordinarios  9949040.90           NaN
# 28                                        NaN         NaN           NaN
# ...

# %%
# Convierto el DataFrame a un archivo .csv
df2020.to_csv('Estado de Ingresos y Gastos Madrid 2020.csv', index=False)
